# %%
precios_cop = [150,50,250,190,700,60,30,20,10]
umbral = 300
print('precios mayores a', umbral)
for p in precios_cop:
    if p >= umbral:
        print(p)
# Out:
# precios mayores a 300
# 700

# %%
valores = [10, None, 15, 50, None, 200, 30]
tope = 150

for v in valores:
    if v is None:
        continue
    if v > tope:
        print(f'Encontrado valor > a top ({v}), deteniendo...')
        break
    print('OK',v)
# Out:
# OK 10
# OK 15
# OK 50
# Encontrado valor > a top (200), deteniendo...
